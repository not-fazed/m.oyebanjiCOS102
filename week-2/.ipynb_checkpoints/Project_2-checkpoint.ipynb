# %%
import numpy as NM
print ("What operation would you like to perform?")  
print ("1. Root of the cubic equation")
print ("2. The root of the quartic equation")
print ("3. The root of a quardratic equation")
choice = input("Choose an input (1-3):")
if choice == "1":
    print ("You chose Cubic equation")
elif choice == "2":
    print ("You chose quartic equation")
elif choice == "3":
    print ("You chose quadratic equation")
else:
    print ("Invalid choice")
if choice == "1":
    a = input("What is your first coefficient?")
    b = input("What is your second coefficient?")
    c = input("What is your third Coefficient?")
    d = input("What is your constant?")

    cubic = [a,b,c,d]
    roots = NM.roots(cubic)
    print "Roots:", roots)
    
elif choice == "2":
    a = input("What is your first coefficient?")
    b = input("What is your second coefficient?")
    c = input("What is your third Coefficient?")
    d = input("What is your fourth coefficent?")
    e = input("What is your constant?")

    quartic = [a,b,c,d,e]
    roots = NM.roots(quartic)
    print "Roots:", roots)
    
elif choice == "3":
    a = input("What is your first cofficient?")
    b = input("What is your second coefficient?")
    c = input("What is your constant?")

    QE = (b**2) - (4*a*c)

    if QE > 0:
        r1 = (-b + D**0.5) / (2*a)
        r2 = (-b - D**0.5) / (2*a)
        print("Roots:", r1,r2)
    elif QE == 0:
        r = -b/(2*a)
        print("Roots:", r)
    else:
        print("Complex roots")
# Out:
# What operation would you like to perform?
# 1. Root of the cubic equation
# 2. The root of the quartic equation
# 3. The root of a quardratic equation
# Choose an input (1-3): 2
# You chose quartic equation
# What is your first coefficient? 2
# What is your second coefficient? 2
# What is your third Coefficient? 2
# What is your fourth coefficent? 2
# What is your constant? 2
